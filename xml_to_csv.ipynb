# %%
import os
import glob
import pandas as pd
import xml.etree.ElementTree as ET


def xml_to_csv(path):
    xml_list = []
    for xml_file in glob.glob(os.path.join(path, "*xml")):
        print(xml_file)
        tree = ET.parse(xml_file)
        root = tree.getroot()
        print(xml_file)
        for member in root.findall('object'):
            value = (root.find('filename').text,
                     int(root.find('size')[0].text),
                     int(root.find('size')[1].text),
                     member[0].text,
                     int(member[4][0].text),
                     int(member[4][1].text),
                     int(member[4][2].text),
                     int(member[4][3].text)
                     )
            xml_list.append(value)
            print(xml_list)
            
    column_name = ['filename', 'width', 'height', 'class', 'xmin', 'ymin', 'xmax', 'ymax']
    xml_df = pd.DataFrame(xml_list, columns=column_name)
    return xml_df

    
def main():
        image_path = os.path.join("F:/object_detection/models/research/object_detection/dataset/test")
        print(image_path)
        xml_df = xml_to_csv(image_path)
        xml_df.to_csv('F:/object_detection/models/research/object_detection/data_2/test_labels.csv', index=None)
        #xml_df.to_csv('F:/object_deteaction/models/research/object_detection/data_2/{}_labels.csv'.format(directory), index=None)
        print('Successfully converted xml to csv.')


main()
# Out:
# F:/object_detection/models/research/object_detection/dataset/test
# F:/object_detection/models/research/object_detection/dataset/test\richard-iwaki-4oJynMdKhsk-unsplash (1).xml
# F:/object_detection/models/research/object_detection/dataset/test\richard-iwaki-4oJynMdKhsk-unsplash (1).xml
# [('richard-iwaki-4oJynMdKhsk-unsplash (1).jpg', 6794, 4532, 'knife', 236, 65, 6579, 4365)]
# F:/object_detection/models/research/object_detection/dataset/test\richard-iwaki-4oJynMdKhsk-unsplash.xml
# F:/object_detection/models/research/object_detection/dataset/test\richard-iwaki-4oJynMdKhsk-unsplash.xml
# [('richard-iwaki-4oJynMdKhsk-unsplash (1).jpg', 6794, 4532, 'knife', 236, 65, 6579, 4365), ('richard-iwaki-4oJynMdKhsk-unsplash.jpg', 6794, 4532, 'knife', 207, 72, 6571, 4344)]
# F:/object_detection/models/research/object_detection/dataset/test\richard-iwaki-WNSNIC5Gf6o-unsplash (1).xml
# F:/object_detection/models/research/object_detection/dataset/test\richard-iwaki-WNSNIC5Gf6o-unsplash (1).xml
# ...
